# %%
import csv
import urllib.request
import codecs
import pandas as pd

# %%
patient_dataset = pd.read_csv('/home/nikita/Desktop/thesis/dataset.csv') 
X = patient_dataset.iloc[:, :].values

# %%
hospital_dataset = pd.read_csv('/home/nikita/Desktop/thesis/hospital_dataset.csv')
Y = hospital_dataset.iloc[:, :].values

# %%
p_df = pd.DataFrame(X)
p_df.head()
# Out:
#       0                  1                            2   3       4       5   \
# 0  36306         Yee, David         929 Clay St, Ste 405  19  female    27.9
# 1  61829     Reddy, Lalitha             591 W Putnam Ave  18    male   33.77
# 2  14152  AGUILAR, VIRGINIA        7862 E FIRESTONE BLVD  28    male      33
# 3  12997        PRING, MAYA  3020 CHILDREN'S WAY, MC5003  33    male  22.705
# 4  40801           Lim, Bun    3030 W Olympic Blvd, #206  32    male   28.88
#
#   6    7  8  9    ...                11     12     13    14         15  \
# 0  0  yes  0  0   ...           Private  Urban  83.84  21.1  southwest
# 1  1   no  0  1   ...     Self-employed  Rural  179.5    26  southeast
# 2  3   no  0  0   ...          children  Rural  95.16  21.2  southeast
# 3  0   no  0  0   ...           Private  Urban  94.76  23.4  northwest
# 4  0   no  0  0   ...          Govt_job  Rural  83.57  27.6  northwest
#
#               16                               17          18       19  \
# ...

# %%
 p_df.rename(columns = {0: 'id',
                        1: 'Provider Name',
                        2: 'Business Address',
                        3 : 'age',
                        4: 'sex', 
                        5: 'bmi', 
                        6: 'children', 
                        7 : 'smoker', 
                        8 : 'hypertension', 
                        9: 'heart_disease',
                        10 : 'ever_married',
                        11: 'work_type',
                        12: 'Residence_type', 
                        13: 'avg_glucoselevel',
                        14: 'bmi',
                        15: 'region',
                        16: 'City', 
                        17: 'Guardian Name',
                        18: 'ID',
                        19: 'Longitude',
                        20: 'Latitude'})
# Out:
#          id            Provider Name  \
# 0     36306               Yee, David
# 1     61829           Reddy, Lalitha
# 2     14152        AGUILAR, VIRGINIA
# 3     12997              PRING, MAYA
# 4     40801                 Lim, Bun
# 5      9348          Kostishack, Amy
# 6     51550            Davis, Julian
# 7     60512         Berthold, Robert
# 8     31309             Choi, Myeong
# 9     39199  Seneviratna, Swarnapali
# 10    15160          Saucedo, Bertha
# 11    21705          BOWER, KIMBERLY
# 12    19042             LUNA, AILEEN
# 13    12249            LUNA, CELLINI
# 14    33104         Kilkenny, Thomas
# 15    55264            tejani, nasir
# 16    29445       VALENCIA, RAINILDA
# 17    49013            Nelson, David
# 18      276         Karpowicz, Scott
# 19    47721             Pan, Carolyn
# 20    19656            singh, balbir
# 21    35806          Kannan, Nirmala
# 22    70637  Arteaga-Hernandez, Edna
# 23    62010          Hernandez, Raul
# ...

# %%
h_df = pd.DataFrame(Y)
h_df.head()
# Out:
#       0                               1                           2   \
# 0  10005   MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH
# 1  10012  DEKALB REGIONAL MEDICAL CENTER        200 MED CENTER DRIVE
# 2  10032                WEDOWEE HOSPITAL       209 NORTH MAIN STREET
# 3  10095            HALE COUNTY HOSPITAL            508 GREEN STREET
# 4  10131        CRESTWOOD MEDICAL CENTER          ONE HOSPITAL DR SE
#
#            3   4      5         6           7                     8   \
# 0        BOAZ  AL  35957  MARSHALL  2565938310  Acute Care Hospitals
# 1  FORT PAYNE  AL  35968   DE KALB  2568453150  Acute Care Hospitals
# 2     WEDOWEE  AL  36278  RANDOLPH  2563572111  Acute Care Hospitals
# 3  GREENSBORO  AL  36744      HALE  3346243024  Acute Care Hospitals
# 4  HUNTSVILLE  AL  35801   MADISON  2568823100  Acute Care Hospitals
#
#                                             9     10    11             12  \
# ...

# %%
h_df.rename(columns = {0: 'Provider ID',
1: 'Hospital Name',
2: 'Address',
3: 'City',
4: 'State',
5: 'Zip_Code',
6: 'Country name',
7: 'Phone Number',
8: 'Hospital type',
9: 'Hospital ownership',
10: 'Emergency services',
11: 'Meets criteria for meaningful use of EHRs',
12: 'Hospital overall rating',
13: 'Location'
 })
# Out:
#      Provider ID                                 Hospital Name  \
# 0          10005                 MARSHALL MEDICAL CENTER SOUTH
# 1          10012                DEKALB REGIONAL MEDICAL CENTER
# 2          10032                              WEDOWEE HOSPITAL
# 3          10095                          HALE COUNTY HOSPITAL
# 4          10131                      CRESTWOOD MEDICAL CENTER
# 5          11304                      CHOCTAW GENERAL HOSPITAL
# 6          20018            YUKON KUSKOKWIM DELTA REG HOSPITAL
# 7          21308                NORTON SOUND REGIONAL HOSPITAL
# 8          21309                            KANAKANAK HOSPITAL
# 9          21310                        MANIILAQ HEALTH CENTER
# 10         30071                 FORT DEFIANCE INDIAN HOSPITAL
# 11         30073    TUBA CITY REGIONAL HEALTH CARE CORPORATION
# 12         30074                                SELLS HOSPITAL
# 13         30077                  SAN CARLOS APACHE HEALTHCARE
# ...
